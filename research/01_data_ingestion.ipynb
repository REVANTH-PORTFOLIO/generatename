# %%
import os

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from src.classifier.constants import *
from src.classifier.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 from src.classifier.constants import *
# ----> 2 from src.classifier.utils.common import read_yaml, create_directories
#
# File ~/generatename/src/classifier/utils/common.py:7
#       5 import json
#       6 import joblib
# ----> 7 from ensure import ensure_annotations
#       8 from box import ConfigBox
#       9 from pathlib import Path
#
# File ~/generatename/.venv/lib/python3.12/site-packages/ensure/__init__.py:4
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 4 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_raises_regex, ensure_annotations
#
# File ~/generatename/.venv/lib/python3.12/site-packages/ensure/main.py:922
#     919 check = Check()
#     921 ensure_raises = unittest_case.assertRaises
# --> 922 ensure_raises_regex = unittest_case.assertRaisesRegexp
#
# AttributeError: 'TestCase' object has no attribute 'assertRaisesRegexp'

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = "config/config.yaml",
        params_filepath = "params.yaml"):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
          root_dir=config.root_dir,
          source_url=config.source_URL,
          local_data_file=config.local_data_file,
          unzip_dir=config.unzip_dir
        )

        return data_ingestion_config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class ConfigurationManager:
#       2     def __init__(
#       3         self,
#       4         config_filepath = "config/config.yaml",
#       5         params_filepath = "params.yaml"):
#       7         self.config = read_yaml(config_filepath)
#
# Cell In[3], line 12, in ConfigurationManager()
#       8     self.params = read_yaml(params_filepath)
#      10     create_directories([self.config.artifacts_root])
# ---> 12 def get_data_ingestion_config(self) -> DataIngestionConfig:
#      13     config = self.config.data_ingestion
#      15     create_directories([config.root_dir])
#
# NameError: name 'DataIngestionConfig' is not defined
